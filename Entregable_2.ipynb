# %% [markdown]
# # EXTRACCIÓN DE API

# %%
# %pip install -r requirements.txt
#Requirements generado al finalizar mediante CLI  "python -m pip freeze > requirements.txt"

import psycopg2
import requests
import json
import os
import pandas as pd
from dotenv import load_dotenv
from psycopg2 import extras

def get_data_api(url):
    # Realiza la solicitud a la API
    response = requests.get(url)
    
    # Verifica si la solicitud fue exitosa (código de estado 200)
    if response.status_code == 200:
        # Devuelve los datos en formato JSON
        return response.json()
    else:
        # Si la solicitud falla, imprime un mensaje de error
        print("Error al obtener datos de la API:", response.status_code)
        return None
    
def execute_read_query(connection, query):
    #Conexion a db mediante cursor
    cursor = connection.cursor()
    result = None
    try:
        #Ejecuto Query para visualizar tabla
        cursor.execute(query)
        #Guardo resultado y devuelvo a main
        result = cursor.fetchall()
        return result
    except Error as e:
        #En el caso de fallar, me devuelve error especifico
        print(f"Error '{e}' ha ocurrido")

# URL de la API CoinCap
url_api = "https://api.coincap.io/v2/assets"

# Obtener los datos desde la API y Normalizarlos
df_coincap = pd.json_normalize(get_data_api(url_api), record_path =['data'], meta=['timestamp'])

# Limpieza de datos
df_coincap = df_coincap.drop(columns=['rank'])
df_coincap['timestamp'] = pd.to_datetime(df_coincap['timestamp'])

#Ordeno por precio en el mercado
df_coincap.sort_values(by='priceUsd',ascending=False)

df_coincap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: certifi==2024.2.2 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: comm==0.2.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: greenlet==3.0.3 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: idna==3.6 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 5)) (3.6)
# Requirement already satisfied: numpy==1.26.4 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: pandas==2.2.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: psycopg2==2.9.9 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 8)) (2.9.9)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: python-decouple==3.8 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 10)) (3.8)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: pytz==2024.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: requests==2.31.0 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 13)) (2.31.0)
# Requirement already satisfied: six==1.16.0 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 14)) (1.16.0)
# Requirement already satisfied: SQLAlchemy==1.4.51 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 15)) (1.4.51)
# Requirement already satisfied: traitlets==5.14.2 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 16)) (5.14.2)
# Requirement already satisfied: tzdata==2024.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 17)) (2024.1)
# Requirement already satisfied: urllib3==2.2.1 in c:\users\jorge\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from -r requirements.txt (line 18)) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
#                     id symbol                name  \
# 0              bitcoin    BTC             Bitcoin
# 1             ethereum    ETH            Ethereum
# 2               tether   USDT              Tether
# 3         binance-coin    BNB                 BNB
# 4               solana    SOL              Solana
# ..                 ...    ...                 ...
# 95             zilliqa    ZIL             Zilliqa
# 96          frax-share    FXS          Frax Share
# 97                holo    HOT                Holo
# 98  trust-wallet-token    TWT  Trust Wallet Token
# 99      xinfin-network    XDC      XinFin Network
#
#                            supply                    maxSupply  \
# 0       19658368.0000000000000000    21000000.0000000000000000
# 1      120077426.1898597300000000                         None
# 2   103618183617.7160800000000000                         None
# 3      166801148.0000000000000000   166801148.0000000000000000
# 4      443884942.2473194000000000                         None
# ..                            ...                          ...
# 95   17372203179.0000000000000000                         None
# 96      78569938.8041846500000000                         None
# 97  173116448035.6735200000000000                         None
# 98     416649900.0000000000000000  1000000000.0000000000000000
# 99   12293293518.5500000000000000                         None
#
#                       marketCapUsd                 volumeUsd24Hr  \
# 0   1239842091171.2541008357592192  23621927058.6897515727498006
# 1    387763136438.2711570397818727  13301139000.7089932477161664
# 2    103582881905.5091020788685091  46816494673.7322418192783800
# 3     86488042581.3710863519265460   1750066158.5340613645926744
# 4     77891860381.5093517669200092   4181869075.9954983239770164
# ..                             ...                           ...
# 95      544541314.8104044901056692     46857891.9857182960805514
# 96      541213942.2940065393131574      1247929.0864300334460220
# 97      534018782.5044589369677882     14716179.9963508926586714
# 98      527674822.7912073222424500     14006029.1916204721918640
# 99      517833469.3554209283530140      6873196.1548064652513434
#
#                   priceUsd    changePercent24Hr                vwap24Hr  \
# 0   63069.4313572344408669  -6.0021292091575375  64102.2618018736750264
# 1    3229.2758825889698025  -6.7666431729709135   3305.0147720541273410
# 2       0.9996593096793009  -0.0733901524956665      0.9997391118945902
# 3     518.5098760913269395  -4.9256142635033719    521.2856551169677770
# 4     175.4775910783437642  -9.2229965366107424    180.4689281857954834
# ..                     ...                  ...                     ...
# 95      0.0313455529617948   1.0282530933788695      0.0305121149664175
# 96      6.8883080543417883  -8.4728400188993991      7.0582140317248481
# 97      0.0030847374040069  -5.1185620642068627      0.0030487266241244
# 98      1.2664705374733255  -1.4465537946562264      1.2558538662675467
# 99      0.0421232494427986  -3.1168440394771152      0.0427950938300280
#
#                                              explorer  \
# 0                            https://blockchain.info/
# 1                               https://etherscan.io/
# 2              https://www.omniexplorer.info/asset/31
# 3   https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4                        https://explorer.solana.com/
# ..                                                ...
# 95  https://etherscan.io/token/0x05f4a42e251f2d52b...
# 96  https://etherscan.io/token/0x3432b6a60d23ca0df...
# 97  https://etherscan.io/token/0x6c6ee5e31d828de24...
# 98         https://explorer.binance.org/asset/TWT-8C2
# 99  https://etherscan.io/token/0x41ab1b6fcbb2fa9dc...
#
#                        timestamp
# 0  1970-01-01 00:28:30.896537141
# 1  1970-01-01 00:28:30.896537141
# 2  1970-01-01 00:28:30.896537141
# 3  1970-01-01 00:28:30.896537141
# 4  1970-01-01 00:28:30.896537141
# ..                           ...
# 95 1970-01-01 00:28:30.896537141
# 96 1970-01-01 00:28:30.896537141
# 97 1970-01-01 00:28:30.896537141
# 98 1970-01-01 00:28:30.896537141
# 99 1970-01-01 00:28:30.896537141
#
# [100 rows x 12 columns]

# %% [markdown]
# # CONEXION A DB

# %%
load_dotenv() 
user = os.getenv("USER")
pwd = os.getenv("PWD")
host = os.getenv("HOST")
db = os.getenv("DB")

#Nos conectamos a la base de datos
try:
    conn = psycopg2.connect(
        host=host,
        dbname=db,
        user=user,
        password=pwd,
        port='5439'
    )
    print("Conectado a Redshift")
    
except Exception as e:
    print("Error de conexion a Redshift")
    print(e)
# Out:
# Conectado a Redshift

# %% [markdown]
# # ENVIO DE DATAFRAME

# %%
#Conversion de df a tupla
tuplas = [tuple(x) for x in df_coincap.to_numpy()]

#Conexion a db 
cursor = conn.cursor()

#Query para insertar valores
insert_query = "INSERT INTO criptos_price (id, symbol, name, supply, maxSupply, marketCapUsd, volumeUsd24Hr, priceUsd, changePercent24Hr, vwap24Hr, explorer, timestamp) VALUES %s"

#Crear la tabla si no existe
cursor.execute("""
            CREATE TABLE IF NOT EXISTS criptos_price(
	        id varchar(40) NOT NULL,
	        symbol varchar (20) UNIQUE,
	        name varchar (100),
	        supply decimal (20,2),
	        maxSupply decimal (20,2),
 	        marketCapUsd decimal (20,2),
	        volumeUsd24Hr decimal (20,2),
	        priceUsd decimal (20,2),
	        changePercent24Hr decimal (20,2),
	        vwap24Hr decimal (20,2),
	        explorer varchar (120),
	        timestamp timestamp,
	        PRIMARY key (id)
            )
        """)

#Limpio tabla para actualizar contenido
cursor.execute("TRUNCATE TABLE criptos_price")

#Insertar los datos en la base de datos
extras.execute_values(cursor, insert_query, tuplas)

# Confirmar los cambios
conn.commit()

# %% [markdown]
# # COMPROBAMOS LOS DATOS CARGADOS

# %%
#Verifico los datos cargados en RedShift mediante consulta
query_db = "SELECT name as cripto, priceUsd as cotizacion FROM criptos_price"
cursor.execute(query_db)
columnas = [description[0] for description in cursor.description]
cursor.fetchall()
print (pd.DataFrame(execute_read_query(conn, query_db),columns=columnas))
# Out:
#                 cripto cotizacion
# 0              Bitcoin   63069.43
# 1             Ethereum    3229.28
# 2               Tether       1.00
# 3                  BNB     518.51
# 4               Solana     175.48
# ..                 ...        ...
# 95             Zilliqa       0.03
# 96          Frax Share       6.89
# 97                Holo       0.00
# 98  Trust Wallet Token       1.27
# 99      XinFin Network       0.04
#
# [100 rows x 2 columns]

# %%
# Cerrar conexión
cursor.close()
conn.close()
